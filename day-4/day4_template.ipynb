# %%
# If not already activated:
conda activate datavis

# %%
conda install <optional packages that might be useful>

# %%
pip install matplotlib-venn

# %% [markdown]
# [Matplotlib 3D Plotting Documentation](https://matplotlib.org/stable/gallery/mplot3d/index.html)
