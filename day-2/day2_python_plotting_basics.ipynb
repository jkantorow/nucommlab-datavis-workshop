# %% [markdown]
# # Day 2: Python Plotting Basics with Matplotlib and Seaborn

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('pub_trend_example_data.csv')
